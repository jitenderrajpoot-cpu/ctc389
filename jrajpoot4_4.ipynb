# %% [markdown]
# <a href="https://colab.research.google.com/github/jitenderrajpoot-cpu/ctc389/blob/main/jrajpoot4_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Jitender Rajpoot

f = float(input("Enter temperature"))

def convert(f):
  c = (f-32) * (5/9)
  print(f, "Fahrenheit in Celsius is: ")
  return(c)

convert(f)
# Out:
# Enter temperature4
# 4.0 Fahrenheit in Celsius is:
# -15.555555555555557
